# %% [markdown]
# # Training neural network: Data augmentation
#
# Tiếp nối bài thực hành trên lớp, bài tập về nhà này vẫn sử dụng MNIST là tập dữ liệu thử nghiệm. Mục tiêu là cải thiện hiệu suất của mô hình bằng các kỹ thuật Augmentation nhằm tăng cường số lượng dữ liệu

# %%
import warnings

from imgaug.augmenters import CropAndPad, Flipud, Affine, AverageBlur
from keras.src.ops.image import GaussianBlur
from tensorflow.python.layers.core import dropout
from torchvision.transforms.v2.functional import affine

warnings.filterwarnings('ignore')
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from keras.datasets import mnist
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %load_ext tensorboard
# !rm -rf './graph/dropout/dropout=0.5,relu/'
# Out:
# 2025-10-09 10:57:25.861940: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-09 10:57:25.890478: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-09 10:57:26.710923: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print('Training image: ', x_train.shape)
print('Testing image: ', x_test.shape)
print('Training label: ', y_train.shape)
print('Testing label: ', y_test.shape)

print(type(x_train))
# Out:
# Training image:  (60000, 28, 28)
# Testing image:  (10000, 28, 28)
# Training label:  (60000,)
# Testing label:  (10000,)
# <class 'numpy.ndarray'>

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
class SimpleModel(nn.Module):
    def __init__(self, dropout_rate):
        super(SimpleModel, self).__init__()
        self.dense_1 = nn.Linear(28*28, 128)
        self.dropout = nn.Dropout(dropout_rate) #trong training thì mỗi neuron có xác suất bị drop
        self.dense_2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        x = x.view(x.size(0), -1) #flatten
        x = self.dense_1(x)
        x = self.relu(x)
        x = self.dropout(x)
        logits = self.dense_2(x)
        output = F.log_softmax(logits, dim=1)
        
        return output

# %% [markdown]
# # Check model parameter

# %%
# simple_model = SimpleModel(dropout_rate = 0.5).cuda()
simple_model = SimpleModel(dropout_rate = 0.5)
for param in simple_model.parameters():
    if param.requires_grad:
        print('param autograd')
        break

# input = torch.rand(1, 28, 28).cuda()
input = torch.rand(1, 28, 28)
output = simple_model(input)  # type: torch.Tensor

model_parameters = filter(lambda p: p.requires_grad, simple_model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print('Number of parameter:', params)
# Out:
# param autograd
# Number of parameter: 101770

# %% [markdown]
# ## Tăng thêm dữ liệu (data augmentation) với thư viện imgaug
#
# Trong phần thực hành này, chúng ta sẽ làm quen với các phương pháp tăng dữ liệu cho bài toán xử lý ảnh, các phương pháp này hoàn toàn có thể lập trình sử dụng thư viện numpy (vì bản chất của phương pháp là ta thao tác trên ma trận biểu diễn ảnh). Tuy nhiên, để việc lập trình được nhanh chóng, chúng ta sẽ làm quen với một thư viện rất mạnh mẽ, giúp ta nhanh chóng cài đặt nhiều phương pháp tăng dữ liệu hiệu quả khác nhau: thư viện imgaug
#
# Để cài đặt imgaug, ta sử dụng lệnh:
#
# pip install imgaug
#
# pip install scikit-image --upgrade

# %%
# Cài đặt thư viện

######################
### YOUR CODE HERE ###
######################
# !pip install imgaug
# !pip install scikit-image --upgrade
# Out:
# Requirement already satisfied: imgaug in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (0.4.0)
# Requirement already satisfied: six in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (1.26.4)
# Requirement already satisfied: scipy in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (1.16.2)
# Requirement already satisfied: Pillow in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (11.3.0)
# Requirement already satisfied: matplotlib in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (3.10.6)
# Requirement already satisfied: scikit-image>=0.14.2 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (0.25.2)
# Requirement already satisfied: opencv-python in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (4.11.0.86)
# Requirement already satisfied: imageio in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (2.37.0)
# Requirement already satisfied: Shapely in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from imgaug) (2.1.2)
# Requirement already satisfied: networkx>=3.0 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image>=0.14.2->imgaug) (3.5)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image>=0.14.2->imgaug) (2025.10.4)
# Requirement already satisfied: packaging>=21 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image>=0.14.2->imgaug) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image>=0.14.2->imgaug) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from matplotlib->imgaug) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from matplotlib->imgaug) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from matplotlib->imgaug) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from matplotlib->imgaug) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from matplotlib->imgaug) (2.9.0.post0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-image in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image) (1.16.2)
# Requirement already satisfied: networkx>=3.0 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image) (2025.10.4)
# Requirement already satisfied: packaging>=21 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/bonxom/Code/ISE_Lab/.venv/lib/python3.12/site-packages (from scikit-image) (0.4)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
from imgaug import augmenters as iaa

# %% [markdown]
# Để tìm hiểu lần lượt các phương pháp, thử áp dụng trên ảnh cat.jpg trong thư mục bài thực hành:

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# !ls drive/MyDrive/AIAcademy/AIAcademyDL02/

# %%
image = cv2.imread('concat.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Các phương pháp thường sử dụng
#
# Các phương pháp hay được sử dụng nhất trong các bài toán xử lý ảnh có thể tham khảo tại: https://imgaug.readthedocs.io/en/latest/source/augmenters.html

# %% [markdown]
# 1. CropAndPad: Cắt hoặc thêm các pixel vào ảnh.

# %%
# Sử dụng hàm CropAndPad với tham số percent=(-0.25, 0.25)
# mỗi cạnh được lấy ngẫu nhiên trong khoảng [-25%, +25%] chiều ảnh -> có thể cắt hoặc pad.
######################
### YOUR CODE HERE ###
######################
crop_and_pad = iaa.CropAndPad(percent=(-0.25, 0.25))
plt.imshow(cv2.cvtColor(crop_and_pad.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 2. Flip: Flip left-right hoặc Flip up-down một số ảnh trong tập ảnh truyền vào

# %%
# Flip left-right sử dụng hàm Fliplr với tham số 1.0

######################
### YOUR CODE HERE ###
######################
flip_lr = iaa.Fliplr(p=1) #p = probability
plt.imshow(cv2.cvtColor(flip_lr.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Flip up-down sử dụng hàm Flipud với tham số 1.0

######################
### YOUR CODE HERE ###
######################
flip_ud = iaa.Flipud(p=1)
plt.imshow(cv2.cvtColor(flip_ud.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Affine: Các phép biến đổi affine như scale, rotate, translate:

# %%
# Biến đổi affine dùng hàm Affine với các tham số scale=(0.5, 1.5), rotate=(-15,15), translate_percent=(-0.2, 0.2)

######################
### YOUR CODE HERE ###
######################
affine = iaa.Affine(scale=(0.5, 1.5), rotate=(-30, 30), translate_percent=(-0.2, 0.5))
plt.imshow(cv2.cvtColor(affine.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Blur: Sử dụng các bộ lọc Gaussian hoặc Mean:

# %%
# Sử dụng hàm AverageBlur để thực hiện Mean filter với tham số k = (11,31), GaussianBlur để thực hiện Gausian Blur với Sigma = (5,15)

######################
### YOUR CODE HERE ###
######################
avg_blur = iaa.AverageBlur(k=(11, 31))
gauss_blur = iaa.GaussianBlur(sigma=(5, 15))

plt.imshow(cv2.cvtColor(avg_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(gauss_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Dropout: Biến đổi ngẫu nhiên một phần ảnh thành các pixel đen

# %%
# Dropout với tham số p = (0, 0.2) 

######################
### YOUR CODE HERE ###
######################
dropout = iaa.Dropout(p=(0, 0.2))
plt.imshow(cv2.cvtColor(dropout.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Kết hợp nhiều augmenter
#
# Trong thực tế, có nhiều chiến lược trong việc thực hiện các augmenter khác nhau, thư viện imgaug cũng hỗ trợ một số hàm để thực hiện công việc này:

# %% [markdown]
# - Sequential: Áp dụng các augmenter lần lượt theo thứ tự truyền vào:

# %%
aug = iaa.Sequential([
    iaa.Affine(translate_px={"x":(-40, 40)}),
    iaa.AdditiveGaussianNoise(scale=0.1*255)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - SomeOf: Áp dụng ngẫu nhiên một vài augmenter trong list các augmenter:

# %%
if not hasattr(np, "bool"):   np.bool   = np.bool_ #np ko np.bool nhưng hàm SomeOf sử dụng np.bool

aug = iaa.SomeOf(2, [
    iaa.Affine(rotate=45),
    iaa.AdditiveGaussianNoise(scale=0.2*255),
    iaa.Add(100, per_channel=True), #add 100 pixel in each kernel
    iaa.Sharpen(alpha=0.5)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Sometimes: Áp dụng augmenter với xác suất p:

# %%
aug = iaa.Sometimes(0.5, iaa.GaussianBlur(sigma=20.0))

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Kết hợp cùng thư viện Keras
#
# Bây giờ chúng ta sẽ sử dụng các augmenter đã viết để thực hiện augment image trong quá trình huấn luyện mạng với thư viện Keras.

# %% [markdown]
# - Bước 1: Khởi tạo Augmenter:

# %%
 # Sử dụng hàm Dropout với tham số p=(0, 0.002)

######################
### YOUR CODE HERE ###
######################

dropout = iaa.Dropout(p=(0, 0.002))
plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))

# %% [markdown]
# - Bước 2: Xây dựng generator:

# %%
class Generator(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels

    def __len__(self):
        return self.images.shape[0]

    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

# %%
training_data = Generator(x_train, y_train)
train_dataloader = DataLoader(training_data, batch_size=32, shuffle=True)

# %%
test_data = Generator(x_test, y_test)
test_dataloader = DataLoader(test_data, batch_size=32, shuffle=True)

# %% [markdown]
# Quan sát thử kết quả của generator bên trên:

# %%
for (batch_idx, target_tuple) in enumerate(train_dataloader):
    print(target_tuple[0].shape)
    for i in range(32):
        plt.subplot(4, 8, i + 1), plt.imshow(target_tuple[0][i], cmap='gray')
    plt.show()
    break
# Out:
# torch.Size([32, 28, 28])

# %% [markdown]
# - Bước 3: Train model với fit_generator:

# %%
use_cuda = torch.cuda.is_available()  #GPU cuda
best_loss = float('inf')

model = SimpleModel(dropout_rate = 0.5)

optimizer = torch.optim.Adadelta(model.parameters())

if use_cuda:
    model = torch.nn.parallel.DataParallel(model.cuda())   # , device_ids=[0, 1, 2, 3]
    torch.backends.cudnn.benchmark = True

# %%
def train(epoch):
    print('\n ############################# Train phase, Epoch: {} #############################'.format(epoch))
    model.train()
    train_loss = 0

    print('\nLearning rate at this epoch is: ', optimizer.param_groups[0]['lr'], '\n')

    for (batch_idx, target_tuple) in enumerate(train_dataloader):
        if use_cuda:
            target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

        images, labels = target_tuple
        # Convert label to long type pytorch
        labels = torch.tensor(labels,dtype=torch.long)

        optimizer.zero_grad()  # zero the gradient buff
        output_tuple = model(images)

        loss = F.nll_loss(output_tuple, labels)

        loss.backward()  # retain_graph=True
        optimizer.step()

        train_loss += loss.item()  # loss　　　
        print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(train_dataloader), ',   ',
              'Train loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), train_loss / (batch_idx + 1)))

    global best_loss
    train_loss /= len(train_dataloader)
    if train_loss < best_loss:
      noti = 'best_'
      best_loss = train_loss
    else:
      noti = ''
    print('saving...')
    state = {
      'weights': (model.module if hasattr(model, 'module') else model).state_dict(),
      'optimizer_weight': optimizer.state_dict(),
      'train_loss': train_loss,
      'epoch': epoch,
    }
    os.makedirs('checkpoints', exist_ok=True)
    torch.save(state, 'checkpoints/model_' + noti + str(epoch) + '_epoch.pth')

# %%
def test(epoch):
    print('\n ############################# Test phase, Epoch: {} #############################'.format(epoch))
    model.eval()
    with torch.no_grad():
        test_loss = 0

        for (batch_idx, target_tuple) in enumerate(test_dataloader):
            if use_cuda:
                target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

            images, labels = target_tuple
            # Convert label to long type pytorch
            labels = torch.tensor(labels,dtype=torch.long)
            output_tuple = model(images)

            loss = F.nll_loss(output_tuple, labels)

            test_loss += loss.item()  # loss　　　
            print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(test_dataloader), ',   ',
                  'Test loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), test_loss / (batch_idx + 1)))

# %%
no_epoch = 5
for epoch in range(no_epoch):
    train(epoch)
    test(epoch)
# Out:
#  ############################# Train phase, Epoch: 0 #############################
#
# Learning rate at this epoch is:  1.0
#
# ########################### Epoch: 0 , --  batch: 0 / 1875 ,    Train loss: 0.065, accumulated average loss: 0.065 ##############################
# ########################### Epoch: 0 , --  batch: 1 / 1875 ,    Train loss: 0.020, accumulated average loss: 0.043 ##############################
# ########################### Epoch: 0 , --  batch: 2 / 1875 ,    Train loss: 0.030, accumulated average loss: 0.039 ##############################
# ########################### Epoch: 0 , --  batch: 3 / 1875 ,    Train loss: 0.206, accumulated average loss: 0.080 ##############################
# ########################### Epoch: 0 , --  batch: 4 / 1875 ,    Train loss: 0.221, accumulated average loss: 0.109 ##############################
# ########################### Epoch: 0 , --  batch: 5 / 1875 ,    Train loss: 0.006, accumulated average loss: 0.092 ##############################
# ########################### Epoch: 0 , --  batch: 6 / 1875 ,    Train loss: 0.031, accumulated average loss: 0.083 ##############################
# ########################### Epoch: 0 , --  batch: 7 / 1875 ,    Train loss: 0.390, accumulated average loss: 0.121 ##############################
# ########################### Epoch: 0 , --  batch: 8 / 1875 ,    Train loss: 0.063, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 0 , --  batch: 9 / 1875 ,    Train loss: 0.041, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 0 , --  batch: 10 / 1875 ,    Train loss: 0.369, accumulated average loss: 0.131 ##############################
# ########################### Epoch: 0 , --  batch: 11 / 1875 ,    Train loss: 0.262, accumulated average loss: 0.142 ##############################
# ########################### Epoch: 0 , --  batch: 12 / 1875 ,    Train loss: 0.051, accumulated average loss: 0.135 ##############################
# ########################### Epoch: 0 , --  batch: 13 / 1875 ,    Train loss: 0.024, accumulated average loss: 0.127 ##############################
# ########################### Epoch: 0 , --  batch: 14 / 1875 ,    Train loss: 0.168, accumulated average loss: 0.130 ##############################
# ########################### Epoch: 0 , --  batch: 15 / 1875 ,    Train loss: 0.107, accumulated average loss: 0.129 ##############################
# ########################### Epoch: 0 , --  batch: 16 / 1875 ,    Train loss: 0.029, accumulated average loss: 0.123 ##############################
# ########################### Epoch: 0 , --  batch: 17 / 1875 ,    Train loss: 0.097, accumulated average loss: 0.121 ##############################
# ########################### Epoch: 0 , --  batch: 18 / 1875 ,    Train loss: 0.061, accumulated average loss: 0.118 ##############################
# ########################### Epoch: 0 , --  batch: 19 / 1875 ,    Train loss: 0.148, accumulated average loss: 0.120 ##############################
# ########################### Epoch: 0 , --  batch: 20 / 1875 ,    Train loss: 0.322, accumulated average loss: 0.129 ##############################
# ########################### Epoch: 0 , --  batch: 21 / 1875 ,    Train loss: 0.075, accumulated average loss: 0.127 ##############################
# ########################### Epoch: 0 , --  batch: 22 / 1875 ,    Train loss: 0.083, accumulated average loss: 0.125 ##############################
# ########################### Epoch: 0 , --  batch: 23 / 1875 ,    Train loss: 0.153, accumulated average loss: 0.126 ##############################
# ########################### Epoch: 0 , --  batch: 24 / 1875 ,    Train loss: 0.053, accumulated average loss: 0.123 ##############################
# ########################### Epoch: 0 , --  batch: 25 / 1875 ,    Train loss: 0.175, accumulated average loss: 0.125 ##############################
# ########################### Epoch: 0 , --  batch: 26 / 1875 ,    Train loss: 0.137, accumulated average loss: 0.126 ##############################
# ########################### Epoch: 0 , --  batch: 27 / 1875 ,    Train loss: 0.319, accumulated average loss: 0.133 ##############################
# ########################### Epoch: 0 , --  batch: 28 / 1875 ,    Train loss: 0.059, accumulated average loss: 0.130 ##############################
# ########################### Epoch: 0 , --  batch: 29 / 1875 ,    Train loss: 0.121, accumulated average loss: 0.130 ##############################
# ########################### Epoch: 0 , --  batch: 30 / 1875 ,    Train loss: 0.261, accumulated average loss: 0.134 ##############################
# ########################### Epoch: 0 , --  batch: 31 / 1875 ,    Train loss: 0.202, accumulated average loss: 0.136 ##############################
# ########################### Epoch: 0 , --  batch: 32 / 1875 ,    Train loss: 0.105, accumulated average loss: 0.135 ##############################
# ########################### Epoch: 0 , --  batch: 33 / 1875 ,    Train loss: 0.074, accumulated average loss: 0.133 ##############################
# ########################### Epoch: 0 , --  batch: 34 / 1875 ,    Train loss: 0.499, accumulated average loss: 0.144 ##############################
# ########################### Epoch: 0 , --  batch: 35 / 1875 ,    Train loss: 0.128, accumulated average loss: 0.143 ##############################
# ########################### Epoch: 0 , --  batch: 36 / 1875 ,    Train loss: 0.184, accumulated average loss: 0.144 ##############################
# ########################### Epoch: 0 , --  batch: 37 / 1875 ,    Train loss: 0.428, accumulated average loss: 0.152 ##############################
# ########################### Epoch: 0 , --  batch: 38 / 1875 ,    Train loss: 0.054, accumulated average loss: 0.149 ##############################
# ########################### Epoch: 0 , --  batch: 39 / 1875 ,    Train loss: 0.471, accumulated average loss: 0.157 ##############################
# ########################### Epoch: 0 , --  batch: 40 / 1875 ,    Train loss: 0.063, accumulated average loss: 0.155 ##############################
# ########################### Epoch: 0 , --  batch: 41 / 1875 ,    Train loss: 0.418, accumulated average loss: 0.161 ##############################
# ########################### Epoch: 0 , --  batch: 42 / 1875 ,    Train loss: 0.157, accumulated average loss: 0.161 ##############################
# ########################### Epoch: 0 , --  batch: 43 / 1875 ,    Train loss: 0.086, accumulated average loss: 0.160 ##############################
# ########################### Epoch: 0 , --  batch: 44 / 1875 ,    Train loss: 0.073, accumulated average loss: 0.158 ##############################
# ########################### Epoch: 0 , --  batch: 45 / 1875 ,    Train loss: 0.022, accumulated average loss: 0.155 ##############################
# ########################### Epoch: 0 , --  batch: 46 / 1875 ,    Train loss: 0.242, accumulated average loss: 0.157 ##############################
# ########################### Epoch: 0 , --  batch: 47 / 1875 ,    Train loss: 0.040, accumulated average loss: 0.154 ##############################
# ########################### Epoch: 0 , --  batch: 48 / 1875 ,    Train loss: 0.120, accumulated average loss: 0.153 ##############################
# ########################### Epoch: 0 , --  batch: 49 / 1875 ,    Train loss: 0.029, accumulated average loss: 0.151 ##############################
# ########################### Epoch: 0 , --  batch: 50 / 1875 ,    Train loss: 0.115, accumulated average loss: 0.150 ##############################
# ########################### Epoch: 0 , --  batch: 51 / 1875 ,    Train loss: 0.227, accumulated average loss: 0.152 ##############################
# ########################### Epoch: 0 , --  batch: 52 / 1875 ,    Train loss: 0.512, accumulated average loss: 0.159 ##############################
# ########################### Epoch: 0 , --  batch: 53 / 1875 ,    Train loss: 0.058, accumulated average loss: 0.157 ##############################
# ########################### Epoch: 0 , --  batch: 54 / 1875 ,    Train loss: 0.053, accumulated average loss: 0.155 ##############################
# ########################### Epoch: 0 , --  batch: 55 / 1875 ,    Train loss: 0.149, accumulated average loss: 0.155 ##############################
# ########################### Epoch: 0 , --  batch: 56 / 1875 ,    Train loss: 0.510, accumulated average loss: 0.161 ##############################
# ########################### Epoch: 0 , --  batch: 57 / 1875 ,    Train loss: 0.328, accumulated average loss: 0.164 ##############################
# ########################### Epoch: 0 , --  batch: 58 / 1875 ,    Train loss: 0.142, accumulated average loss: 0.163 ##############################
# ########################### Epoch: 0 , --  batch: 59 / 1875 ,    Train loss: 0.080, accumulated average loss: 0.162 ##############################
# ########################### Epoch: 0 , --  batch: 60 / 1875 ,    Train loss: 0.216, accumulated average loss: 0.163 ##############################
# ########################### Epoch: 0 , --  batch: 61 / 1875 ,    Train loss: 0.365, accumulated average loss: 0.166 ##############################
# ########################### Epoch: 0 , --  batch: 62 / 1875 ,    Train loss: 0.210, accumulated average loss: 0.167 ##############################
# ########################### Epoch: 0 , --  batch: 63 / 1875 ,    Train loss: 0.769, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 64 / 1875 ,    Train loss: 0.107, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 65 / 1875 ,    Train loss: 0.252, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 66 / 1875 ,    Train loss: 0.084, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 67 / 1875 ,    Train loss: 0.189, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 68 / 1875 ,    Train loss: 0.373, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 69 / 1875 ,    Train loss: 0.206, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 70 / 1875 ,    Train loss: 0.160, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 71 / 1875 ,    Train loss: 0.192, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 72 / 1875 ,    Train loss: 0.320, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 73 / 1875 ,    Train loss: 0.520, accumulated average loss: 0.185 ##############################
# ########################### Epoch: 0 , --  batch: 74 / 1875 ,    Train loss: 0.037, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 75 / 1875 ,    Train loss: 0.393, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 76 / 1875 ,    Train loss: 0.298, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 77 / 1875 ,    Train loss: 0.305, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 78 / 1875 ,    Train loss: 0.647, accumulated average loss: 0.194 ##############################
# ########################### Epoch: 0 , --  batch: 79 / 1875 ,    Train loss: 0.118, accumulated average loss: 0.194 ##############################
# ########################### Epoch: 0 , --  batch: 80 / 1875 ,    Train loss: 0.109, accumulated average loss: 0.192 ##############################
# ########################### Epoch: 0 , --  batch: 81 / 1875 ,    Train loss: 0.034, accumulated average loss: 0.191 ##############################
# ########################### Epoch: 0 , --  batch: 82 / 1875 ,    Train loss: 0.556, accumulated average loss: 0.195 ##############################
# ########################### Epoch: 0 , --  batch: 83 / 1875 ,    Train loss: 0.146, accumulated average loss: 0.194 ##############################
# ########################### Epoch: 0 , --  batch: 84 / 1875 ,    Train loss: 0.094, accumulated average loss: 0.193 ##############################
# ########################### Epoch: 0 , --  batch: 85 / 1875 ,    Train loss: 0.123, accumulated average loss: 0.192 ##############################
# ########################### Epoch: 0 , --  batch: 86 / 1875 ,    Train loss: 0.237, accumulated average loss: 0.193 ##############################
# ########################### Epoch: 0 , --  batch: 87 / 1875 ,    Train loss: 0.193, accumulated average loss: 0.193 ##############################
# ########################### Epoch: 0 , --  batch: 88 / 1875 ,    Train loss: 0.230, accumulated average loss: 0.193 ##############################
# ########################### Epoch: 0 , --  batch: 89 / 1875 ,    Train loss: 0.108, accumulated average loss: 0.192 ##############################
# ########################### Epoch: 0 , --  batch: 90 / 1875 ,    Train loss: 0.008, accumulated average loss: 0.190 ##############################
# ########################### Epoch: 0 , --  batch: 91 / 1875 ,    Train loss: 0.033, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 92 / 1875 ,    Train loss: 0.059, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 93 / 1875 ,    Train loss: 0.056, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 94 / 1875 ,    Train loss: 0.019, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 95 / 1875 ,    Train loss: 0.040, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 96 / 1875 ,    Train loss: 0.306, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 97 / 1875 ,    Train loss: 0.202, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 98 / 1875 ,    Train loss: 0.532, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 99 / 1875 ,    Train loss: 0.067, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 100 / 1875 ,    Train loss: 0.293, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 101 / 1875 ,    Train loss: 0.124, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 102 / 1875 ,    Train loss: 0.027, accumulated average loss: 0.185 ##############################
# ########################### Epoch: 0 , --  batch: 103 / 1875 ,    Train loss: 0.016, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 104 / 1875 ,    Train loss: 0.216, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 105 / 1875 ,    Train loss: 0.287, accumulated average loss: 0.185 ##############################
# ########################### Epoch: 0 , --  batch: 106 / 1875 ,    Train loss: 0.079, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 107 / 1875 ,    Train loss: 0.017, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 108 / 1875 ,    Train loss: 0.438, accumulated average loss: 0.185 ##############################
# ########################### Epoch: 0 , --  batch: 109 / 1875 ,    Train loss: 0.082, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 110 / 1875 ,    Train loss: 0.150, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 111 / 1875 ,    Train loss: 0.254, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 112 / 1875 ,    Train loss: 0.016, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 113 / 1875 ,    Train loss: 0.452, accumulated average loss: 0.185 ##############################
# ########################### Epoch: 0 , --  batch: 114 / 1875 ,    Train loss: 0.212, accumulated average loss: 0.185 ##############################
# ########################### Epoch: 0 , --  batch: 115 / 1875 ,    Train loss: 0.453, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 116 / 1875 ,    Train loss: 0.351, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 117 / 1875 ,    Train loss: 0.025, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 118 / 1875 ,    Train loss: 0.274, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 119 / 1875 ,    Train loss: 0.144, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 120 / 1875 ,    Train loss: 0.150, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 121 / 1875 ,    Train loss: 0.015, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 122 / 1875 ,    Train loss: 0.436, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 123 / 1875 ,    Train loss: 0.027, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 124 / 1875 ,    Train loss: 0.040, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 125 / 1875 ,    Train loss: 0.197, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 126 / 1875 ,    Train loss: 0.762, accumulated average loss: 0.190 ##############################
# ########################### Epoch: 0 , --  batch: 127 / 1875 ,    Train loss: 0.011, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 128 / 1875 ,    Train loss: 0.153, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 129 / 1875 ,    Train loss: 0.230, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 130 / 1875 ,    Train loss: 0.091, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 131 / 1875 ,    Train loss: 0.288, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 132 / 1875 ,    Train loss: 0.111, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 133 / 1875 ,    Train loss: 0.148, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 134 / 1875 ,    Train loss: 0.393, accumulated average loss: 0.190 ##############################
# ########################### Epoch: 0 , --  batch: 135 / 1875 ,    Train loss: 0.168, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 136 / 1875 ,    Train loss: 0.141, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 137 / 1875 ,    Train loss: 0.277, accumulated average loss: 0.190 ##############################
# ########################### Epoch: 0 , --  batch: 138 / 1875 ,    Train loss: 0.422, accumulated average loss: 0.191 ##############################
# ########################### Epoch: 0 , --  batch: 139 / 1875 ,    Train loss: 0.196, accumulated average loss: 0.191 ##############################
# ########################### Epoch: 0 , --  batch: 140 / 1875 ,    Train loss: 0.075, accumulated average loss: 0.191 ##############################
# ########################### Epoch: 0 , --  batch: 141 / 1875 ,    Train loss: 0.202, accumulated average loss: 0.191 ##############################
# ########################### Epoch: 0 , --  batch: 142 / 1875 ,    Train loss: 0.227, accumulated average loss: 0.191 ##############################
# ########################### Epoch: 0 , --  batch: 143 / 1875 ,    Train loss: 0.060, accumulated average loss: 0.190 ##############################
# ########################### Epoch: 0 , --  batch: 144 / 1875 ,    Train loss: 0.021, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 145 / 1875 ,    Train loss: 0.038, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 146 / 1875 ,    Train loss: 0.150, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 147 / 1875 ,    Train loss: 0.418, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 148 / 1875 ,    Train loss: 0.188, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 149 / 1875 ,    Train loss: 0.184, accumulated average loss: 0.189 ##############################
# ########################### Epoch: 0 , --  batch: 150 / 1875 ,    Train loss: 0.072, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 151 / 1875 ,    Train loss: 0.074, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 152 / 1875 ,    Train loss: 0.183, accumulated average loss: 0.188 ##############################
# ########################### Epoch: 0 , --  batch: 153 / 1875 ,    Train loss: 0.124, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 154 / 1875 ,    Train loss: 0.125, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 155 / 1875 ,    Train loss: 0.140, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 156 / 1875 ,    Train loss: 0.308, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 157 / 1875 ,    Train loss: 0.086, accumulated average loss: 0.187 ##############################
# ########################### Epoch: 0 , --  batch: 158 / 1875 ,    Train loss: 0.067, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 159 / 1875 ,    Train loss: 0.199, accumulated average loss: 0.186 ##############################
# ########################### Epoch: 0 , --  batch: 160 / 1875 ,    Train loss: 0.042, accumulated average loss: 0.185 ##############################
# ########################### Epoch: 0 , --  batch: 161 / 1875 ,    Train loss: 0.176, accumulated average loss: 0.185 ##############################
# ########################### Epoch: 0 , --  batch: 162 / 1875 ,    Train loss: 0.055, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 163 / 1875 ,    Train loss: 0.034, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 164 / 1875 ,    Train loss: 0.133, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 165 / 1875 ,    Train loss: 0.257, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 166 / 1875 ,    Train loss: 0.089, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 167 / 1875 ,    Train loss: 0.087, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 168 / 1875 ,    Train loss: 0.055, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 169 / 1875 ,    Train loss: 0.218, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 170 / 1875 ,    Train loss: 0.149, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 171 / 1875 ,    Train loss: 0.057, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 172 / 1875 ,    Train loss: 0.060, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 173 / 1875 ,    Train loss: 0.134, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 174 / 1875 ,    Train loss: 0.356, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 175 / 1875 ,    Train loss: 0.106, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 176 / 1875 ,    Train loss: 0.075, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 177 / 1875 ,    Train loss: 0.071, accumulated average loss: 0.179 ##############################
# ########################### Epoch: 0 , --  batch: 178 / 1875 ,    Train loss: 0.034, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 179 / 1875 ,    Train loss: 0.058, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 180 / 1875 ,    Train loss: 0.147, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 181 / 1875 ,    Train loss: 0.297, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 182 / 1875 ,    Train loss: 0.067, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 183 / 1875 ,    Train loss: 0.110, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 184 / 1875 ,    Train loss: 0.023, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 185 / 1875 ,    Train loss: 0.203, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 186 / 1875 ,    Train loss: 0.315, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 187 / 1875 ,    Train loss: 0.265, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 188 / 1875 ,    Train loss: 0.150, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 189 / 1875 ,    Train loss: 0.223, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 190 / 1875 ,    Train loss: 0.074, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 191 / 1875 ,    Train loss: 0.242, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 192 / 1875 ,    Train loss: 0.046, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 193 / 1875 ,    Train loss: 0.061, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 194 / 1875 ,    Train loss: 0.138, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 195 / 1875 ,    Train loss: 0.084, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 196 / 1875 ,    Train loss: 0.046, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 197 / 1875 ,    Train loss: 0.491, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 198 / 1875 ,    Train loss: 0.217, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 199 / 1875 ,    Train loss: 0.172, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 200 / 1875 ,    Train loss: 0.434, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 201 / 1875 ,    Train loss: 0.140, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 202 / 1875 ,    Train loss: 0.076, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 203 / 1875 ,    Train loss: 0.542, accumulated average loss: 0.179 ##############################
# ########################### Epoch: 0 , --  batch: 204 / 1875 ,    Train loss: 0.226, accumulated average loss: 0.179 ##############################
# ########################### Epoch: 0 , --  batch: 205 / 1875 ,    Train loss: 0.223, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 206 / 1875 ,    Train loss: 0.301, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 207 / 1875 ,    Train loss: 0.047, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 208 / 1875 ,    Train loss: 0.066, accumulated average loss: 0.179 ##############################
# ########################### Epoch: 0 , --  batch: 209 / 1875 ,    Train loss: 0.059, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 210 / 1875 ,    Train loss: 0.158, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 211 / 1875 ,    Train loss: 0.018, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 212 / 1875 ,    Train loss: 0.252, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 213 / 1875 ,    Train loss: 0.015, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 214 / 1875 ,    Train loss: 0.088, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 215 / 1875 ,    Train loss: 0.033, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 216 / 1875 ,    Train loss: 0.091, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 217 / 1875 ,    Train loss: 0.350, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 218 / 1875 ,    Train loss: 0.059, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 219 / 1875 ,    Train loss: 0.104, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 220 / 1875 ,    Train loss: 0.042, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 221 / 1875 ,    Train loss: 0.038, accumulated average loss: 0.174 ##############################
# ########################### Epoch: 0 , --  batch: 222 / 1875 ,    Train loss: 0.051, accumulated average loss: 0.174 ##############################
# ########################### Epoch: 0 , --  batch: 223 / 1875 ,    Train loss: 0.215, accumulated average loss: 0.174 ##############################
# ########################### Epoch: 0 , --  batch: 224 / 1875 ,    Train loss: 0.059, accumulated average loss: 0.174 ##############################
# ########################### Epoch: 0 , --  batch: 225 / 1875 ,    Train loss: 0.306, accumulated average loss: 0.174 ##############################
# ########################### Epoch: 0 , --  batch: 226 / 1875 ,    Train loss: 0.045, accumulated average loss: 0.174 ##############################
# ########################### Epoch: 0 , --  batch: 227 / 1875 ,    Train loss: 0.156, accumulated average loss: 0.173 ##############################
# ########################### Epoch: 0 , --  batch: 228 / 1875 ,    Train loss: 0.260, accumulated average loss: 0.174 ##############################
# ########################### Epoch: 0 , --  batch: 229 / 1875 ,    Train loss: 0.529, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 230 / 1875 ,    Train loss: 0.292, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 231 / 1875 ,    Train loss: 0.164, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 232 / 1875 ,    Train loss: 0.294, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 233 / 1875 ,    Train loss: 0.070, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 234 / 1875 ,    Train loss: 0.143, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 235 / 1875 ,    Train loss: 0.192, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 236 / 1875 ,    Train loss: 0.303, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 237 / 1875 ,    Train loss: 0.261, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 238 / 1875 ,    Train loss: 0.178, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 239 / 1875 ,    Train loss: 0.097, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 240 / 1875 ,    Train loss: 0.019, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 241 / 1875 ,    Train loss: 0.048, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 242 / 1875 ,    Train loss: 0.246, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 243 / 1875 ,    Train loss: 0.317, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 244 / 1875 ,    Train loss: 0.083, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 245 / 1875 ,    Train loss: 0.145, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 246 / 1875 ,    Train loss: 0.275, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 247 / 1875 ,    Train loss: 0.218, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 248 / 1875 ,    Train loss: 0.117, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 249 / 1875 ,    Train loss: 0.251, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 250 / 1875 ,    Train loss: 0.201, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 251 / 1875 ,    Train loss: 0.209, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 252 / 1875 ,    Train loss: 0.162, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 253 / 1875 ,    Train loss: 0.351, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 254 / 1875 ,    Train loss: 0.075, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 255 / 1875 ,    Train loss: 0.105, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 256 / 1875 ,    Train loss: 0.065, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 257 / 1875 ,    Train loss: 0.060, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 258 / 1875 ,    Train loss: 0.057, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 259 / 1875 ,    Train loss: 0.247, accumulated average loss: 0.175 ##############################
# ########################### Epoch: 0 , --  batch: 260 / 1875 ,    Train loss: 0.384, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 261 / 1875 ,    Train loss: 0.082, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 262 / 1875 ,    Train loss: 0.195, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 263 / 1875 ,    Train loss: 0.405, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 264 / 1875 ,    Train loss: 0.022, accumulated average loss: 0.176 ##############################
# ########################### Epoch: 0 , --  batch: 265 / 1875 ,    Train loss: 0.295, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 266 / 1875 ,    Train loss: 0.185, accumulated average loss: 0.177 ##############################
# ########################### Epoch: 0 , --  batch: 267 / 1875 ,    Train loss: 0.552, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 268 / 1875 ,    Train loss: 0.066, accumulated average loss: 0.178 ##############################
# ########################### Epoch: 0 , --  batch: 269 / 1875 ,    Train loss: 0.703, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 270 / 1875 ,    Train loss: 0.255, accumulated average loss: 0.180 ##############################
# ########################### Epoch: 0 , --  batch: 271 / 1875 ,    Train loss: 0.593, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 272 / 1875 ,    Train loss: 0.059, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 273 / 1875 ,    Train loss: 0.128, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 274 / 1875 ,    Train loss: 0.330, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 275 / 1875 ,    Train loss: 0.096, accumulated average loss: 0.181 ##############################
# ########################### Epoch: 0 , --  batch: 276 / 1875 ,    Train loss: 0.448, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 277 / 1875 ,    Train loss: 0.123, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 278 / 1875 ,    Train loss: 0.427, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 279 / 1875 ,    Train loss: 0.059, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 280 / 1875 ,    Train loss: 0.187, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 281 / 1875 ,    Train loss: 0.165, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 282 / 1875 ,    Train loss: 0.076, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 283 / 1875 ,    Train loss: 0.319, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 284 / 1875 ,    Train loss: 0.194, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 285 / 1875 ,    Train loss: 0.482, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 286 / 1875 ,    Train loss: 0.075, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 287 / 1875 ,    Train loss: 0.431, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 288 / 1875 ,    Train loss: 0.361, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 289 / 1875 ,    Train loss: 0.093, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 290 / 1875 ,    Train loss: 0.084, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 291 / 1875 ,    Train loss: 0.054, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 292 / 1875 ,    Train loss: 0.301, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 293 / 1875 ,    Train loss: 0.051, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 294 / 1875 ,    Train loss: 0.293, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 295 / 1875 ,    Train loss: 0.033, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 296 / 1875 ,    Train loss: 0.386, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 297 / 1875 ,    Train loss: 0.299, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 298 / 1875 ,    Train loss: 0.032, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 299 / 1875 ,    Train loss: 0.171, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 300 / 1875 ,    Train loss: 0.085, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 301 / 1875 ,    Train loss: 0.077, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 302 / 1875 ,    Train loss: 0.324, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 303 / 1875 ,    Train loss: 0.147, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 304 / 1875 ,    Train loss: 0.144, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 305 / 1875 ,    Train loss: 0.053, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 306 / 1875 ,    Train loss: 0.159, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 307 / 1875 ,    Train loss: 0.034, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 308 / 1875 ,    Train loss: 0.119, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 309 / 1875 ,    Train loss: 0.241, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 310 / 1875 ,    Train loss: 0.119, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 311 / 1875 ,    Train loss: 0.084, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 312 / 1875 ,    Train loss: 0.426, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 313 / 1875 ,    Train loss: 0.193, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 314 / 1875 ,    Train loss: 0.137, accumulated average loss: 0.182 ##############################
# ########################### Epoch: 0 , --  batch: 315 / 1875 ,    Train loss: 0.274, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 316 / 1875 ,    Train loss: 0.207, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 317 / 1875 ,    Train loss: 0.309, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 318 / 1875 ,    Train loss: 0.056, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 319 / 1875 ,    Train loss: 0.179, accumulated average loss: 0.183 ##############################
# ########################### Epoch: 0 , --  batch: 320 / 1875 ,    Train loss: 0.548, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 321 / 1875 ,    Train loss: 0.140, accumulated average loss: 0.184 ##############################
# ########################### Epoch: 0 , --  batch: 322 / 1875 ,    Train loss: 0.347, accumulated average loss: 0.184 ##############################
